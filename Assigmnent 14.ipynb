# %% [markdown]
# **Q1** What does RGBA stand for?

# %% [markdown]
# **Answer**:-

# %% [markdown]
# RGBA stands for red green blue alpha. While it is sometimes described as a color space, it is actually a three-channel RGB color model supplemented with a fourth alpha channel. Alpha indicates how opaque each pixel is and allows an image to be combined over others using alpha compositing, with transparent areas and anti-aliasing of the edges of opaque regions.

# %% [markdown]
# **Q2** From the Pillow module, how do you get the RGBA value of any images?

# %% [markdown]
# **Answer**:-

# %% [markdown]
# from PIL library import Image, Image.open() is used to open image and from PIL import ImageColor we can use ImageColour.getrgb() function to get RGBA value.

# %% [markdown]
# **Example:-**

# %%
from PIL import Image
my_image=Image.open(r"D:\python program\car1.png")

# %%
my_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=498x339 at 0x13F3A962790>

# %%
from PIL import ImageColor

# %%
my_image=ImageColor.getcolor("violet", "P")

# %%
my_image2=ImageColor.getcolor("violet", 'RGBA')

# %%
print(my_image2)
# Out:
# (238, 130, 238, 255)

# %%
print(my_image)
# Out:
# (238, 130, 238)

# %% [markdown]
# **Q3**. What is a box tuple, and how does it work?

# %% [markdown]
# **Answer**:-

# %% [markdown]
#  A box of tuple argument means  a tuple of four integer coordinates that represent a rectangular region in an image
#
# * Left The x-coordinate of the leftmost edge of the box.
#
# * Top The y-coordinate of the top edge of the box.
#
# * Right The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.
#
# * Bottom The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.

# %% [markdown]
# **Example**:-

# %%
from PIL import Image
my_image=Image.open(r"D:\python program\car1.png")

# %%
my_image.size
# Out:
# (498, 339)

# %%
# cropped image using coordinat
width,height=my_image.size
area = (0, 0, width/2, height/2)
crop_my_image =my_image.crop(area)
crop_my_image.save("car2.png")
crop_my_image
# Out:
# <PIL.Image.Image image mode=P size=249x170 at 0x13F3AB12F10>

# %%
print(crop_my_image.size)
# Out:
# (249, 170)

# %% [markdown]
# **Q4**. Use your image and load in notebook then, How can you find out the width and height of an Image object?
#
# **Answer :-**

# %%
from PIL import Image
my_image=Image.open(r"D:\python program\car1.png")
width ,height=my_image.size
width,height
# Out:
# (498, 339)

# %% [markdown]
# **Q5**. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# **Answer**:-

# %%
from PIL import Image
my_image1=Image.open(r"D:\python program\car1.png")
print(my_image1.size)
left = 0
top = 489/2
right = 339/3
bottom = 339
my_image2=my_image1.crop((left,top,right,bottom))
my_image2.save("car2.png")
my_image2
# Out:
# (498, 339)
# <PIL.Image.Image image mode=P size=113x95 at 0x13F3AB41340>

# %% [markdown]
# **Q6**. After making changes to an Image object, how could you save it as an image file?
#
# **Answer :-**

# %%
from PIL import Image, ImageDraw
my_image1=Image.open(r"D:\python program\car1.png")
draw = ImageDraw.Draw(my_image1)
draw.line((0, 0) + my_image1.size, fill=128)
draw.line((0, my_image1.size[1], my_image1.size[0], 0), fill=128)
my_image1.save("my_image.png")
my_image1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=498x339 at 0x13F3AB54C40>

# %% [markdown]
# **Q7**. What module contains Pillow’s shape-drawing code?
#
# **Answer :-**
#
# The ImageDraw module contains code to draw on images

# %%
from PIL import Image, ImageDraw
my_image1=Image.open(r"D:\python program\car1.png")
draw = ImageDraw.Draw(my_image1)
draw.line((0, 0) + my_image1.size, fill=128)
draw.line((0, my_image1.size[1], my_image1.size[0], 0), fill=128)
my_image1.save("my_image.png")
my_image1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=498x339 at 0x13F3AB260A0>

# %% [markdown]
# **Q8**. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# **Answer :-**
#
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle().\ They are returned by passing the Image object to the ImageDraw.Draw() function.
